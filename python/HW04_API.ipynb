# %% [markdown]
# # HW01 - get data from public API

# %%
from requests import get
import pandas as pd

# %%
url = "https://data.binance.com/api/v3/ticker/24hr"

response = get(url)

data = response.json()

# %%
print(data)
# Out:
# [{'symbol': 'ETHBTC', 'priceChange': '0.00000600', 'priceChangePercent': '0.009', 'weightedAvgPrice': '0.06657757', 'prevClosePrice': '0.06671600', 'lastPrice': '0.06672100', 'lastQty': '13.57300000', 'bidPrice': '0.06672100', 'bidQty': '14.84970000', 'askPrice': '0.06672200', 'askQty': '12.81040000', 'openPrice': '0.06671500', 'highPrice': '0.06692500', 'lowPrice': '0.06625500', 'volume': '44303.71250000', 'quoteVolume': '2949.63352101', 'openTime': 1680853746126, 'closeTime': 1680940146126, 'firstId': 411842638, 'lastId': 411930321, 'count': 87684}, {'symbol': 'LTCBTC', 'priceChange': '0.00002100', 'priceChangePercent': '0.653', 'weightedAvgPrice': '0.00323421', 'prevClosePrice': '0.00321800', 'lastPrice': '0.00323900', 'lastQty': '1.09900000', 'bidPrice': '0.00323900', 'bidQty': '85.17100000', 'askPrice': '0.00324100', 'askQty': '44.89000000', 'openPrice': '0.00321800', 'highPrice': '0.00325100', 'lowPrice': '0.00320100', 'volume': '35479.75000000', 'quoteVolume': '114.74878960', 
# ...

# %%
binance = pd.DataFrame(data)

binance.head()
# Out:
#     symbol  priceChange priceChangePercent weightedAvgPrice prevClosePrice  \
# 0   ETHBTC   0.00000600              0.009       0.06657757     0.06671600
# 1   LTCBTC   0.00002100              0.653       0.00323421     0.00321800
# 2   BNBBTC  -0.00004000             -0.359       0.01113142     0.01115000
# 3   NEOBTC   0.00001400              3.248       0.00043853     0.00043200
# 4  QTUMETH   0.00003400              2.025       0.00168331     0.00167300
#
#     lastPrice       lastQty    bidPrice         bidQty    askPrice  ...  \
# 0  0.06672100   13.57300000  0.06672100    14.84970000  0.06672200  ...
# 1  0.00323900    1.09900000  0.00323900    85.17100000  0.00324100  ...
# 2  0.01111000    0.02700000  0.01110900     9.02500000  0.01111000  ...
# 3  0.00044500  126.61000000  0.00044400  1671.82000000  0.00044600  ...
# 4  0.00171300   25.10000000  0.00170600   125.80000000  0.00170900  ...
#
#     openPrice   highPrice    lowPrice           volume    quoteVolume  \
# ...
